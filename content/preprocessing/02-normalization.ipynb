# %% [markdown]
# ## 데이터 로드
#
# 이전에 QC를 거친 tabula muris senis 뇌 데이터셋의 출력물로 계속 작업하고 PCA를 사용하여 결과를 시각화합니다.

# %%
import scanpy as sc

# %%
adata = sc.read('../data/brain_qc.h5ad')

# %%
# ?sc.pl.pca_overview
