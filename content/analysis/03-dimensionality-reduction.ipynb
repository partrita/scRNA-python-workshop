# %% [markdown]
# # 차원 축소
#
# ## 소개
#
# __차원 축소 방법__은 큰 변수 집합을 취하여 원래 데이터셋의 정보 대부분을 여전히 포함하는 더 작은 __구성 요소__ 집합을 반환하려고 합니다. 이는 _정보 손실_과 _향상된 해석 가능성_ 사이의 본질적인 절충을 의미합니다. 모든 차원 축소 방법은 일부 정보를 버리지만, 거대한 값 행렬을 이해하는 데 중요한 역할을 합니다.
#
# 우리는 이미 PCA에서 차원 축소의 한 예를 보았습니다. 이제 차원 축소에 대한 다른 두 가지 일반적인 접근 방식인 tSNE와 UMAP을 살펴보겠습니다.
#
# ## 데이터 로드
# 정규화된 마우스 뇌 데이터로 계속 작업할 것입니다:

# %%
import scanpy as sc

adata = sc.read('../data/brain_normalized.h5ad')
